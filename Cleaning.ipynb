# %%
import pandas as pd
import numpy as np
pd.set_option('precision', 5)

# %%
path = '/data/Dropbox/Data/Asylum_Courts/raw'

# %% [markdown]
# ## Cleaning court_appln.csv Dataset

# %%
court = pd.read_csv(path + '/court_appln.csv', low_memory=False)
# changing these from float data types to categorical so summary stats work
court['idnProceeding'] = court['idnProceeding'].astype('category')
court['idnCase'] = court['idnCase'].astype('category')
court['idnProceedingAppln'] = court['idnProceedingAppln'].astype('category')
# this gives summary stats of the original court.csv
court.count()
# Out:
# idnProceedingAppln    4559071
# idnProceeding         4559069
# idnCase               4559067
# Appl_Code             4559069
# Appl_Recd_Date        4559036
# Appl_Dec              4232861
# dtype: int64

# %%
# this gives summary stats of the original court.csv
court.describe()
# Out:
#         idnProceedingAppln  idnProceeding    idnCase Appl_Code  \
# count              4559071      4559069.0  4559067.0   4559069
# unique             4559071      2219694.0  1942504.0       147
# top                4679486      1177202.0  4611524.0      ASYL
# freq                     1           14.0       45.0   1294601
#
#              Appl_Recd_Date Appl_Dec
# count               4559036  4232861
# unique               252761       17
# top     1997-03-31 00:00:00        D
# freq                   5030  1229245

# %%
# adding placeholder number to count how many applications were filed for idnProceeding
court['numAppsPerProc'] = 1
court['numAppsPerProc'] = court['numAppsPerProc'].astype('int64')
# adding additional feature based on how many applications have been filed for the same (idnCase, idnProceeding) pair
court['numAppsPerProc'] = court.groupby(['idnCase', 'idnProceeding'])['numAppsPerProc'].transform('count')
# dropping all applications with empty decisions
court = court.dropna(subset=['Appl_Dec'])

# %%
court.describe()
# Out:
#        numAppsPerProc
# count    4.232857e+06
# mean     2.581931e+00
# std      1.076856e+00
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      3.000000e+00
# 75%      3.000000e+00
# max      1.400000e+01

# %%
# filtering for applications that have a Deny or Grant decision
court = court[court.Appl_Dec.isin(['D','G'])]
court.count()
# Out:
# idnProceedingAppln    2295485
# idnProceeding         2295485
# idnCase               2295485
# Appl_Code             2295484
# Appl_Recd_Date        2295459
# Appl_Dec              2295485
# numAppsPerProc        2295485
# dtype: int64

# %%
court = court[court.Appl_Code.isin(['ASYL','ASYW', 'WCAT'])]
court.count()
# Out:
# idnProceedingAppln    1151913
# idnProceeding         1151913
# idnCase               1151913
# Appl_Code             1151913
# Appl_Recd_Date        1151911
# Appl_Dec              1151913
# numAppsPerProc        1151913
# dtype: int64

# %%
court.count()
# Out:
# idnProceedingAppln    1151913
# idnProceeding         1151913
# idnCase               1151913
# Appl_Code             1151913
# Appl_Recd_Date        1151911
# Appl_Dec              1151913
# numAppsPerProc        1151913
# dtype: int64

# %%
c

# %% [markdown]
# ## Cleaning master.csv Dataset

# %%
master = pd.read_csv(path + '/master.csv', low_memory=False)

# %%
master.dtypes
# Out:
# idncase             float64
# nat                  object
# case_type            object
# c_asy_type           object
# idnproceeding        object
# base_city_code       object
# hearing_loc_code     object
# dec_type             object
# dec_code             object
# other_comp           object
# osc_date             object
# input_date           object
# comp_date            object
# attorney_flag       float64
# ij_code              object
# tracid              float64
# dtype: object

# %%
master['idncase'] = master['idncase'].astype('category')
master['attorney_flag'] = master['attorney_flag'].astype('category')
master['tracid'] = master['tracid'].astype('category')

# this gives summary stats of the original master.csv
master.describe()
# Out:
#           idncase      nat case_type c_asy_type idnproceeding base_city_code  \
# count   6084423.0  6067662   6084422    1635071       6084437        6084413
# unique  4729150.0      267        23          8       6084437             61
# top     3102179.0       MX       RMV          I       4468438            LOS
# freq         16.0  2147177   4354277     877426             1         573840
#
#        hearing_loc_code dec_type dec_code other_comp   osc_date input_date  \
# count           6082921  4564888  4409689    1339567    6051084    6054693
# unique              330       12       19         10      14510      13032
# top                 LOS        O        X          C  04MAY1989  31MAR1997
# freq             495905  2741447  2105793     581757       2058       6968
#
#         comp_date  attorney_flag  ij_code     tracid
# count     5749361      3039846.0  6044839  5742523.0
# unique      10372            1.0      549      401.0
# top     12JAN1991            1.0       DA       60.0
# freq        13219      3039846.0    79810    79812.0

# %%
# dropping empty dates
master = master.dropna(subset=['osc_date', 'input_date', 'comp_date'])

# %%
master['osc_date'] = master['osc_date'].astype('str')
master['input_date'] = master['input_date'].astype('str')
master['comp_date'] = master['comp_date'].astype('str')

# %%
master.describe()
# Out:
#           idncase      nat case_type c_asy_type idnproceeding base_city_code  \
# count   5714382.0  5712217   5714381    1525404       5714391        5714380
# unique  4513708.0      266        21          5       5714391             54
# top     3102179.0       MX       RMV          I       4468438            LOS
# freq         16.0  2016048   3990682     803890             1         522782
#
#        hearing_loc_code dec_type dec_code other_comp   osc_date input_date  \
# count           5714291  4564532  4409568    1304708    5714391    5714391
# unique              325       10       15         10      14505      12991
# top                 LOS        O        X          C  04MAY1989  31MAR1997
# freq             445958  2741172  2105725     581699       2058       6968
#
#         comp_date  attorney_flag  ij_code     tracid
# count     5714391      2771903.0  5681911  5391579.0
# unique      10359            1.0      545      401.0
# top     12JAN1991            1.0       DA       60.0
# freq        13219      2771903.0    78025    78027.0

# %%
master = master[master['osc_date'].apply(lambda x: len(x) == 9)]
master = master[master['input_date'].apply(lambda x: len(x) == 9)]
master = master[master['comp_date'].apply(lambda x: len(x) == 9)]

# %%
master.describe()
# Out:
#           idncase      nat case_type c_asy_type idnproceeding base_city_code  \
# count   5714382.0  5712217   5714381    1525404       5714391        5714380
# unique  4513708.0      266        21          5       5714391             54
# top     3102179.0       MX       RMV          I       4468438            LOS
# freq         16.0  2016048   3990682     803890             1         522782
#
#        hearing_loc_code dec_type dec_code other_comp   osc_date input_date  \
# count           5714291  4564532  4409568    1304708    5714391    5714391
# unique              325       10       15         10      14505      12991
# top                 LOS        O        X          C  04MAY1989  31MAR1997
# freq             445958  2741172  2105725     581699       2058       6968
#
#         comp_date  attorney_flag  ij_code     tracid
# count     5714391      2771903.0  5681911  5391579.0
# unique      10359            1.0      545      401.0
# top     12JAN1991            1.0       DA       60.0
# freq        13219      2771903.0    78025    78027.0

# %%
master['osc_date'] = pd.to_datetime(master['osc_date'], format='%d%b%Y')
master['input_date'] = pd.to_datetime(master['input_date'], format='%d%b%Y')
master['comp_date'] = pd.to_datetime(master['comp_date'], format='%d%b%Y')

# %%
# this includes datetime columns and their earliest and latest occurrence in the dataset 
master.describe(include='all')
# Out:
#           idncase      nat case_type c_asy_type idnproceeding base_city_code  \
# count   5714382.0  5712217   5714381    1525404       5714391        5714380
# unique  4513708.0      266        21          5       5714391             54
# top     3102179.0       MX       RMV          I       4468438            LOS
# freq         16.0  2016048   3990682     803890             1         522782
# first         NaN      NaN       NaN        NaN           NaN            NaN
# last          NaN      NaN       NaN        NaN           NaN            NaN
#
#        hearing_loc_code dec_type dec_code other_comp             osc_date  \
# count           5714291  4564532  4409568    1304708              5714391
# unique              325       10       15         10                14505
# top                 LOS        O        X          C  1989-05-04 00:00:00
# freq             445958  2741172  2105725     581699                 2058
# first               NaN      NaN      NaN        NaN  1900-01-01 00:00:00
# last                NaN      NaN      NaN        NaN  2013-05-29 00:00:00
#
#                  input_date            comp_date  attorney_flag  ij_code  \
# count               5714391              5714391      2771903.0  5681911
# unique                12991                10359            1.0      545
# top     1997-03-31 00:00:00  1991-01-12 00:00:00            1.0       DA
# freq                   6968                13219      2771903.0    78025
# first   1900-01-01 00:00:00  1951-03-23 00:00:00            NaN      NaN
# last    2013-05-31 00:00:00  2013-05-31 00:00:00            NaN      NaN
#
#            tracid
# count   5391579.0
# unique      401.0
# top          60.0
# freq      78027.0
# first         NaN
# last          NaN

# %%
master = master.drop_duplicates(subset=['idncase', 'idnproceeding'])

# %%
# keeping only affimrative and defensive cases
master = master[master.c_asy_type.isin(['E','I'])]

# %% [markdown]
# ## Cleaning schedule.csv Dataset

# %%
sched = pd.read_csv(path + '/schedule.csv')

# %%
sched['idnschedule'] = sched['idnschedule'].astype('category')
sched['idncase'] = sched['idncase'].astype('category')
sched['idnproceeding'] = sched['idnproceeding'].astype('category')

# %%
# summary stats of original schedule.csv
sched.describe()
# Out:
#         idnschedule     idncase  idnproceeding adj_medium schedule_type  \
# count      15377519  15377502.0       15377519    8825704      15377519
# unique      2748024   4675871.0        5973070          6            24
# top         1270261   5630045.0        4324164          P            --
# freq             11       245.0            215    7487967       9056997
#
#          adj_date
# count    15377519
# unique      12736
# top     31MAR2011
# freq         5846

# %%
sched['adj_date'] = sched['adj_date'].astype('str')
sched = sched[sched['adj_date'].apply(lambda x: len(x) == 9)]
# Out:
#         idnschedule     idncase  idnproceeding adj_medium schedule_type  \
# count      15377519  15377502.0       15377519    8825704      15377519
# unique      2748024   4675871.0        5973070          6            24
# top         1270261   5630045.0        4324164          P            --
# freq             11       245.0            215    7487967       9056997
#
#          adj_date
# count    15377519
# unique      12736
# top     31MAR2011
# freq         5846

# %%
sched['adj_date'] = pd.to_datetime(sched['adj_date'], format='%d%b%Y')
sched.describe()
# Out:
#         idnschedule     idncase  idnproceeding adj_medium schedule_type  \
# count    15377519.0  15377502.0     15377519.0    8825704      15377519
# unique    2748024.0   4675871.0      5973070.0          6            24
# top       1270261.0   5630045.0      4324164.0          P            --
# freq           11.0       245.0          215.0    7487967       9056997
# first           NaN         NaN            NaN        NaN           NaN
# last            NaN         NaN            NaN        NaN           NaN
#
#                    adj_date
# count              15377519
# unique                12736
# top     2011-03-31 00:00:00
# freq                   5846
# first   1951-03-23 00:00:00
# last    2030-07-30 00:00:00

# %%
# need to investigate why there's a 2030 date....
r = sched[sched['adj_date'] == '2030-07-30']
print(r)
# Out:
#         idnschedule    idncase idnproceeding adj_medium schedule_type  \
# 3832862     2132155  6361860.0       5001252          p            MD
#
#           adj_date
# 3832862 2030-07-30
